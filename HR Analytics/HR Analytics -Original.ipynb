# %%
import pandas as pd
import numpy as np 
import seaborn as sns
sns.set()
import matplotlib.pyplot as plt 
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
import os, sys 
os.getcwd()
# Out:
# 'C:\\Users\\Packi\\Downloads\\HR Analytics'

# %%
df_hr = pd.read_csv("Attrition.csv")

# %%
df_hr.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df_hr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df_hr.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
from pandas_profiling import ProfileReport

profile = ProfileReport(df_hr)
profile.to_file(output_file='report.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
import webbrowser

webbrowser.open('report.html')
# Out:
# True

# %%
df_hr.duplicated().sum()
# Out:
# 0

# %%
df_hr.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df_hr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df_hr.corr(), annot=True)
plt.show()

# %% [markdown]
# ### E D A

# %%
df_hr['Attrition'].value_counts().plot(kind='pie',autopct= '%1.2f%%' )
# Out:
# <AxesSubplot:ylabel='Attrition'>

# %%
df_hr.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
# To analyse - Age vs Attrition

sns.distplot(df_hr[df_hr['Attrition']=='No']['Age'],hist=False, label='No')
sns.distplot(df_hr[df_hr['Attrition']=='Yes']['Age'],hist=False,color='r' 
             ,label='Yes')
plt.title("Age vs Attrition of the Employee")
# Out:
# Text(0.5, 1.0, 'Age vs Attrition of the Employee')

# %%
# Relation between Gender vs Attrition
gender_wise = pd.crosstab(df_hr['Gender'], df_hr['Attrition'])
gender_wise.plot(kind='bar')
plt.title("Gender vs Attrition")
# Out:
# Text(0.5, 1.0, 'Gender vs Attrition')

# %%
 # Relation between Deparment vs Attrition
Department_wise = pd.crosstab(df_hr['Department'], df_hr['Attrition'])
Department_wise.plot(kind='bar')
plt.title("Department vs Attrition")
# Out:
# Text(0.5, 1.0, 'Department vs Attrition')

# %%
 # Relation between Years at Company vs Attrition
Department_wise = pd.crosstab(df_hr['YearsAtCompany'], df_hr['Attrition'])
Department_wise.plot(kind='bar')
plt.title("Years at Company vs Attrition")

# %%
 # Relation between Years with Current Manager vs Attrition
Department_wise = pd.crosstab(df_hr['YearsWithCurrManager'], df_hr['Attrition'])
Department_wise.plot(kind='bar')
plt.title(" Years with Current Manager vs Attrition")
# Out:
# Text(0.5, 1.0, ' Years with Current Manager vs Attrition')

# %%
 # Relation between Years in Current Role vs Attrition
Department_wise = pd.crosstab(df_hr['YearsInCurrentRole'], df_hr['Attrition'])
Department_wise.plot(kind='bar')
plt.title(" Years in Current Role vs Attrition")
# Out:
# Text(0.5, 1.0, ' Years in Current Role vs Attrition')

# %%
 # Relation between Education vs Attrition
Department_wise = pd.crosstab(df_hr['Education'], df_hr['Attrition'])
Department_wise.plot(kind='bar')
plt.title(" Education vs Attrition")
# Out:
# Text(0.5, 1.0, ' Education vs Attrition')

# %%
 # Relation between Marital Status vs Attrition
Department_wise = pd.crosstab(df_hr['MaritalStatus'], df_hr['Attrition'])
Department_wise.plot(kind='bar')
plt.title("Marital Status vs Attrition")
# Out:
# Text(0.5, 1.0, 'Marital Status vs Attrition')

# %%
 # Relation between WorkLifeBalance vs Attrition
Department_wise = pd.crosstab(df_hr['WorkLifeBalance'], df_hr['Attrition'])
Department_wise.plot(kind='bar')
plt.title("WorkLifeBalance vs Attrition")
# Out:
# Text(0.5, 1.0, 'WorkLifeBalance vs Attrition')

# %%
# Converting Categorical varibales to Numerical variables using Label Encoder
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df_hr['Attrition'] = le.fit_transform(df_hr['Attrition'])
df_hr['BusinessTravel'] = le.fit_transform(df_hr['BusinessTravel'])
df_hr['Department'] = le.fit_transform(df_hr['Department'])
df_hr['EducationField'] = le.fit_transform(df_hr['EducationField'])
df_hr['Gender'] = le.fit_transform(df_hr['Gender'])
df_hr['MaritalStatus'] = le.fit_transform(df_hr['MaritalStatus'])
df_hr['Over18'] = le.fit_transform(df_hr['Over18'])
df_hr['OverTime'] = le.fit_transform(df_hr['OverTime'])
df_hr['JobRole'] = le.fit_transform(df_hr['JobRole'])

# %%
df_hr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   int32
#  2   BusinessTravel            1470 non-null   int32
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   int32
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   int32
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   int32
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
# Defining the Independent and Dependent Variables 
X = df_hr.drop('Attrition', axis=1)
Y = df_hr['Attrition']

# %%
# Scaling of the data 
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
X_scaled = sc.fit_transform(X)

# %%
arr1 = np.array(Y)
arr2 = arr1.reshape(-1,1)
Y = pd.DataFrame(arr2)

# %%
print(X.shape)
print(Y.shape)
# Out:
# (1470, 34)
# (1470, 1)

# %%
# Checking for imbalancced data 
df_hr['Attrition'].value_counts() # We can see the data is imbalanced
# Out:
# 0    1233
# 1     237
# Name: Attrition, dtype: int64

# %%
# Splitting the Data into train and test 
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X_scaled, Y, test_size=0.2, random_state=42)

# %% [markdown]
# ### Balancing the data using SMOTE Method

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=42)
X_train_resampled, Y_train_resampled = smote.fit_resample(X_train, Y_train)

# %%
# Model Building

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC 
from xgboost import XGBClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,f1_score

# %%
Log = LogisticRegression()
RF = RandomForestClassifier()
DT = DecisionTreeClassifier()
NB = GaussianNB()
SVM = SVC()
Xg = XGBClassifier()
SGD = SGDClassifier()
AB = AdaBoostClassifier()

# %%
Clf = [ Log, RF, DT, NB, SVM, Xg, SGD, AB ]

# %%
print(Clf)
# Out:
# [LogisticRegression(), RandomForestClassifier(), DecisionTreeClassifier(), GaussianNB(), SVC(), XGBClassifier(), SGDClassifier(), AdaBoostClassifier()]

# %%
for i in Clf: 
    print(i)
    clf = i.fit(X_train_resampled,Y_train_resampled)
# Out:
# LogisticRegression()
# RandomForestClassifier()
# DecisionTreeClassifier()
# GaussianNB()
# SVC()
# XGBClassifier()
# SGDClassifier()
# AdaBoostClassifier()

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, f1_score, matthews_corrcoef, \
    roc_auc_score,precision_score, recall_score, \
    average_precision_score

def get_scoring_functions():
    cfuncs = [accuracy_score, f1_score, matthews_corrcoef, recall_score]
    pfuncs = [roc_auc_score, average_precision_score]
    return cfuncs, pfuncs

def get_tuple_cols():
    cfuncs, pfuncs = get_scoring_functions()
    return ['model'] + [f.__name__ for f in cfuncs] + [f.__name__ for f in pfuncs]

def get_scores(model_name, y_true, y_preds):
    cfuncs, pfuncs = get_scoring_functions()

    cscores = {f.__name__: f(y_true, y_preds) for f in cfuncs}
    pscores = {f.__name__: f(y_true, y_preds) for f in pfuncs}

    d = {**cscores, **pscores}
    d['model'] = model_name

    return tuple([d[c] for c in get_tuple_cols()])

models = [Log,RF, DT, NB, SVM, Xg, SGD, AB]
model_names = [type(m).__name__ for m in models]
print("\033[5m"+ "BEFORE APPLYING HYPER PARAMETERS"+"\033[0m\n")
y_preds = {type(model).__name__: model.predict(X_test) for model in models}
scores = [get_scores(name, Y_test, y_preds[name]) for name in model_names]
df = pd.DataFrame(scores, columns=get_tuple_cols())
df=df.sort_values('accuracy_score',ascending=False).reset_index(drop=True)
df=df.style.background_gradient(cmap='viridis')
df
# Out:
# BEFORE APPLYING HYPER PARAMETERS
# <style type="text/css">
# #T_e20cf_row0_col1, #T_e20cf_row2_col2, #T_e20cf_row2_col3, #T_e20cf_row2_col6, #T_e20cf_row6_col4, #T_e20cf_row6_col5 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_e20cf_row0_col2 {
#   background-color: #2fb47c;
#   color: #f1f1f1;
# }
# #T_e20cf_row0_col3 {
#   background-color: #90d743;
#   color: #000000;
# }
# #T_e20cf_row0_col4, #T_e20cf_row4_col4 {
#   background-color: #3e4989;
#   color: #f1f1f1;
# }
# #T_e20cf_row0_col5 {
#   background-color: #25848e;
#   color: #f1f1f1;
# }
# #T_e20cf_row0_col6 {
#   background-color: #63cb5f;
#   color: #000000;
# }
# #T_e20cf_row1_col1 {
#   background-color: #f6e620;
#   color: #000000;
# }
# #T_e20cf_row1_col2 {
#   background-color: #46327e;
#   color: #f1f1f1;
# }
# #T_e20cf_row1_col3 {
#   background-color: #1f968b;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# ## HYPER PARAMETER TUNING RANDOM FOREST

# %%
model_comparison = {}

# %%
from sklearn.model_selection import GridSearchCV

# %%
params = {
    'n_estimators': [100, 200, 300, 500],
    'criterion': ['gini','entropy'],
    'max_depth': [None, 10, 20, 30, 40,50],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]}

# %%
model_grid = GridSearchCV(RF, param_grid=params, cv=5)
model_grid.fit(X_train_resampled, Y_train_resampled)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 10, 20, 30, 40, 50],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [100, 200, 300, 500]})

# %%
 best_rf =model_grid.best_params_

# %%
print(best_rf)
# Out:
# {'criterion': 'gini', 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 500}

# %%
from sklearn.ensemble import RandomForestClassifier
model_grid_RF = RandomForestClassifier(criterion= 'gini', max_depth= 30, min_samples_leaf= 1, min_samples_split= 2, n_estimators= 200, random_state=42)

# %%
model_gridRF=model_grid_RF.fit(X_train_resampled, Y_train_resampled)
Y_pred_gridRF = model_grid_RF.predict(X_test)

# %%
cv_accuracy_RF = cross_val_score(estimator = model_gridRF, X = X_train_resampled, y = Y_train_resampled, cv = 5) 
print(cv_accuracy_RF.mean())
# Out:
# 0.9382052821128453

# %%
print(accuracy_score(Y_test, Y_pred_gridRF))
model_comparison['Random Forest']=[accuracy_score(Y_pred_gridRF,Y_test),f1_score(Y_pred_gridRF,Y_test,average='weighted'), cv_accuracy_RF.mean()]
# Out:
# 0.8673469387755102

# %%
print(classification_report(Y_test, Y_pred_gridRF))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.98      0.93       255
#            1       0.50      0.15      0.24        39
#
#     accuracy                           0.87       294
#    macro avg       0.69      0.57      0.58       294
# weighted avg       0.83      0.87      0.84       294

# %%
print(confusion_matrix(Y_test, Y_pred_gridRF))
# Out:
# [[249   6]
#  [ 33   6]]

# %% [markdown]
# ### HYPER PARAMETER TUNING FOR SVM

# %%
params_SVM ={'C': [1.0, 10, 100, 1000],
                 'kernel':['rbf','sigmoid','linear'],
                 'gamma' : [1,0.01,0.001,0.0001]}

# %%
grid_SVM = GridSearchCV(estimator=SVM, param_grid=params_SVM,cv=5)
grid_SVM.fit(X_train,Y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [1.0, 10, 100, 1000],
#                          'gamma': [1, 0.01, 0.001, 0.0001],
#                          'kernel': ['rbf', 'sigmoid', 'linear']})

# %%
print(grid_SVM.best_params_)
# Out:
# {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}

# %%
model_grid_SVM = SVC(C=100, gamma=0.001, kernel='rbf')
model_grid_SVM.fit(X_train_resampled, Y_train_resampled)
cv_accuracy_SVM = cross_val_score(estimator = model_grid_SVM, X = X_train_resampled, y = Y_train_resampled, cv = 5)

# %%
Y_pred_gridSVM  = model_grid_SVM.predict(X_test)

# %%
print(confusion_matrix(Y_test, Y_pred_gridSVM))
# Out:
# [[204  51]
#  [ 15  24]]

# %%
print(accuracy_score(Y_test, Y_pred_gridSVM))
model_comparison['Support Vector Machine']=[accuracy_score(Y_pred_gridSVM,Y_test),f1_score(Y_pred_gridSVM,Y_test,average='weighted'), cv_accuracy_SVM.mean()]
# Out:
# 0.7755102040816326

# %%
print(cv_accuracy_SVM.mean())
# Out:
# 0.8425504984602536

# %%
print(classification_report(Y_test, Y_pred_gridSVM))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.80      0.86       255
#            1       0.32      0.62      0.42        39
#
#     accuracy                           0.78       294
#    macro avg       0.63      0.71      0.64       294
# weighted avg       0.85      0.78      0.80       294

# %%
Xgb_params = { 'max_depth': [3,5,7,9, 11],
               'n_estimators' : [100,200,300,500], 
               'n_jobs' :[-1], 
               'gamma' :[0, 0.1,0.01,.001],
               'random_state':[42] }

# %%
model_grid_Xgb = GridSearchCV(estimator=Xg, param_grid=Xgb_params, cv=5)
model_grid_Xgb.fit(X_train_resampled, Y_train_resampled)
# Out:
# GridSearchCV(cv=5, estimator=XGBClassifier(),
#              param_grid={'gamma': [0, 0.1, 0.01, 0.001],
#                          'max_depth': [3, 5, 7, 9, 11],
#                          'n_estimators': [100, 200, 300, 500], 'n_jobs': [-1],
#                          'random_state': [42]})

# %%
print(model_grid_Xgb.best_params_)
# Out:
# {'gamma': 0.001, 'max_depth': 9, 'n_estimators': 100, 'n_jobs': -1, 'random_state': 42}

# %%
model_grid_Xgb = XGBClassifier(gamma = 0.001, max_depth =9, n_estimator=100, random_state=42,n_jobs=-1)
model_grid_Xgb.fit(X_train_resampled,Y_train_resampled)
# Out:
# XGBClassifier(gamma=0.001, max_depth=9, n_estimator=100, n_jobs=-1,
#               random_state=42)

# %%
cv_accuracy_Xgb = cross_val_score(estimator = model_grid_Xgb, X = X_train_resampled, y = Y_train_resampled, cv = 5)
print(cv_accuracy_Xgb.mean())
# Out:
# 0.9111461976094786

# %%
Y_pred_gridXgb = model_grid_Xgb.predict(X_test)

# %%
print(confusion_matrix(Y_test,Y_pred_gridXgb))
# Out:
# [[245  10]
#  [ 29  10]]

# %%
print(accuracy_score(Y_test,Y_pred_gridXgb))
model_comparison['XGBoost']=[accuracy_score(Y_pred_gridXgb,Y_test),f1_score(Y_pred_gridXgb,Y_test,average='weighted'), cv_accuracy_Xgb.mean()]
# Out:
# 0.8673469387755102

# %%
print(classification_report(Y_test,Y_pred_gridXgb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.96      0.93       255
#            1       0.50      0.26      0.34        39
#
#     accuracy                           0.87       294
#    macro avg       0.70      0.61      0.63       294
# weighted avg       0.84      0.87      0.85       294

# %%
Model_com_df= pd.DataFrame(model_comparison).T
Model_com_df.columns=['Model Accuracy','Model F1-Score', 'CV Accuracy']
Model_com_df=Model_com_df.sort_values(by='Model F1-Score',ascending=False)
Model_com_df_styled=Model_com_df.style.background_gradient(cmap='YlOrBr',  low=0.75, high=1.0)
Model_com_df_styled
# Out:
# <style type="text/css">
# #T_1c60a_row0_col0, #T_1c60a_row0_col1, #T_1c60a_row0_col2, #T_1c60a_row1_col0 {
#   background-color: #e96d13;
#   color: #f1f1f1;
# }
# #T_1c60a_row1_col1 {
#   background-color: #ef7718;
#   color: #f1f1f1;
# }
# #T_1c60a_row1_col2 {
#   background-color: #f98e23;
#   color: #f1f1f1;
# }
# #T_1c60a_row2_col0, #T_1c60a_row2_col1, #T_1c60a_row2_col2 {
#   background-color: #fede86;
#   color: #000000;
# }
# </style>
# <table id="T_1c60a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1c60a_level0_col0" class="col_heading level0 col0" >Model Accuracy</th>
#       <th id="T_1c60a_level0_col1" class="col_heading level0 col1" >Model F1-Score</th>
#       <th id="T_1c60a_level0_col2" class="col_heading level0 col2" >CV Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1c60a_level0_row0" class="row_heading level0 row0" >Random Forest</th>
# ...
