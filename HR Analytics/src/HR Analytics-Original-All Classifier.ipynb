# %%
import pandas as pd
import numpy as np 
import seaborn as sns
sns.set()
import matplotlib.pyplot as plt 
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
import os, sys 
os.getcwd()
# Out:
# 'C:\\Users\\Packi\\Downloads\\HR Analytics'

# %%
df_hr = pd.read_csv("Attrition.csv")

# %%
df_hr.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
# 2  ...                         2            80                 0
# 3  ...                         3            80                 0
# 4  ...                         4            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
# 2                  7                      3               3               0
# 3                  8                      3               3               8
# 4                  6                      3               3               2
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
# 1                  7                        1                     7
# 2                  0                        0                     0
# 3                  7                        3                     0
# 4                  2                        2                     2
#
# [5 rows x 35 columns]

# %%
df_hr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
#  14  JobLevel                  1470 non-null   int64
#  15  JobRole                   1470 non-null   object
#  16  JobSatisfaction           1470 non-null   int64
#  17  MaritalStatus             1470 non-null   object
#  18  MonthlyIncome             1470 non-null   int64
#  19  MonthlyRate               1470 non-null   int64
#  20  NumCompaniesWorked        1470 non-null   int64
#  21  Over18                    1470 non-null   object
#  22  OverTime                  1470 non-null   object
#  23  PercentSalaryHike         1470 non-null   int64
#  24  PerformanceRating         1470 non-null   int64
#  25  RelationshipSatisfaction  1470 non-null   int64
#  26  StandardHours             1470 non-null   int64
#  27  StockOptionLevel          1470 non-null   int64
#  28  TotalWorkingYears         1470 non-null   int64
#  29  TrainingTimesLastYear     1470 non-null   int64
#  30  WorkLifeBalance           1470 non-null   int64
#  31  YearsAtCompany            1470 non-null   int64
#  32  YearsInCurrentRole        1470 non-null   int64
#  33  YearsSinceLastPromotion   1470 non-null   int64
#  34  YearsWithCurrManager      1470 non-null   int64
# dtypes: int64(26), object(9)
# memory usage: 402.1+ KB

# %%
df_hr.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
from pandas_profiling import ProfileReport

profile = ProfileReport(df_hr)
profile.to_file(output_file='report.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
import webbrowser

webbrowser.open('report.html')
# Out:
# True

# %%
df_hr.duplicated().sum()
# Out:
# 0

# %%
df_hr.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df_hr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
#  14  JobLevel                  1470 non-null   int64
#  15  JobRole                   1470 non-null   object
#  16  JobSatisfaction           1470 non-null   int64
#  17  MaritalStatus             1470 non-null   object
#  18  MonthlyIncome             1470 non-null   int64
#  19  MonthlyRate               1470 non-null   int64
#  20  NumCompaniesWorked        1470 non-null   int64
#  21  Over18                    1470 non-null   object
#  22  OverTime                  1470 non-null   object
#  23  PercentSalaryHike         1470 non-null   int64
#  24  PerformanceRating         1470 non-null   int64
#  25  RelationshipSatisfaction  1470 non-null   int64
#  26  StandardHours             1470 non-null   int64
#  27  StockOptionLevel          1470 non-null   int64
#  28  TotalWorkingYears         1470 non-null   int64
#  29  TrainingTimesLastYear     1470 non-null   int64
#  30  WorkLifeBalance           1470 non-null   int64
#  31  YearsAtCompany            1470 non-null   int64
#  32  YearsInCurrentRole        1470 non-null   int64
#  33  YearsSinceLastPromotion   1470 non-null   int64
#  34  YearsWithCurrManager      1470 non-null   int64
# dtypes: int64(26), object(9)
# memory usage: 402.1+ KB

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df_hr.corr(), annot=True)
plt.show()

# %% [markdown]
# ### E D A

# %%
df_hr['Attrition'].value_counts().plot(kind='pie',autopct= '%1.2f%%' )
# Out:
# <AxesSubplot:ylabel='Attrition'>

# %%
df_hr.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
# To analyse - Age vs Attrition

sns.distplot(df_hr[df_hr['Attrition']=='No']['Age'],hist=False, label='No')
sns.distplot(df_hr[df_hr['Attrition']=='Yes']['Age'],hist=False,color='r' 
             ,label='Yes')
plt.title("Age vs Attrition of the Employee")
# Out:
# Text(0.5, 1.0, 'Age vs Attrition of the Employee')

# %%
# Relation between Gender vs Attrition
gender_wise = pd.crosstab(df_hr['Gender'], df_hr['Attrition'])
gender_wise.plot(kind='bar')
plt.title("Gender vs Attrition")
# Out:
# Text(0.5, 1.0, 'Gender vs Attrition')

# %%
 # Relation between Deparment vs Attrition
Department_wise = pd.crosstab(df_hr['Department'], df_hr['Attrition'])
Department_wise.plot(kind='bar')
plt.title("Department vs Attrition")
# Out:
# Text(0.5, 1.0, 'Department vs Attrition')

# %%
 # Relation between Years at Company vs Attrition
Department_wise = pd.crosstab(df_hr['YearsAtCompany'], df_hr['Attrition'])
Department_wise.plot(kind='bar')
plt.title("Years at Company vs Attrition")
# Out:
# Text(0.5, 1.0, 'Years at Company vs Attrition')

# %%
 # Relation between Years with Current Manager vs Attrition
Department_wise = pd.crosstab(df_hr['YearsWithCurrManager'], df_hr['Attrition'])
Department_wise.plot(kind='bar')
plt.title(" Years with Current Manager vs Attrition")
# Out:
# Text(0.5, 1.0, ' Years with Current Manager vs Attrition')

# %%
 # Relation between Years in Current Role vs Attrition
Department_wise = pd.crosstab(df_hr['YearsInCurrentRole'], df_hr['Attrition'])
Department_wise.plot(kind='bar')
plt.title(" Years in Current Role vs Attrition")
# Out:
# Text(0.5, 1.0, ' Years in Current Role vs Attrition')

# %%
 # Relation between Education vs Attrition
Department_wise = pd.crosstab(df_hr['Education'], df_hr['Attrition'])
Department_wise.plot(kind='bar')
plt.title(" Education vs Attrition")
# Out:
# Text(0.5, 1.0, ' Education vs Attrition')

# %%
 # Relation between Marital Status vs Attrition
Department_wise = pd.crosstab(df_hr['MaritalStatus'], df_hr['Attrition'])
Department_wise.plot(kind='bar')
plt.title("Marital Status vs Attrition")
# Out:
# Text(0.5, 1.0, 'Marital Status vs Attrition')

# %%
 # Relation between WorkLifeBalance vs Attrition
Department_wise = pd.crosstab(df_hr['WorkLifeBalance'], df_hr['Attrition'])
Department_wise.plot(kind='bar')
plt.title("WorkLifeBalance vs Attrition")
# Out:
# Text(0.5, 1.0, 'WorkLifeBalance vs Attrition')

# %%
# Converting Categorical varibales to Numerical variables using Label Encoder
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df_hr['Attrition'] = le.fit_transform(df_hr['Attrition'])
df_hr['BusinessTravel'] = le.fit_transform(df_hr['BusinessTravel'])
df_hr['Department'] = le.fit_transform(df_hr['Department'])
df_hr['EducationField'] = le.fit_transform(df_hr['EducationField'])
df_hr['Gender'] = le.fit_transform(df_hr['Gender'])
df_hr['MaritalStatus'] = le.fit_transform(df_hr['MaritalStatus'])
df_hr['Over18'] = le.fit_transform(df_hr['Over18'])
df_hr['OverTime'] = le.fit_transform(df_hr['OverTime'])
df_hr['JobRole'] = le.fit_transform(df_hr['JobRole'])

# %%
df_hr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   int32
#  2   BusinessTravel            1470 non-null   int32
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   int32
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   int32
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   int32
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
#  14  JobLevel                  1470 non-null   int64
#  15  JobRole                   1470 non-null   int32
#  16  JobSatisfaction           1470 non-null   int64
#  17  MaritalStatus             1470 non-null   int32
#  18  MonthlyIncome             1470 non-null   int64
#  19  MonthlyRate               1470 non-null   int64
#  20  NumCompaniesWorked        1470 non-null   int64
#  21  Over18                    1470 non-null   int32
#  22  OverTime                  1470 non-null   int32
#  23  PercentSalaryHike         1470 non-null   int64
#  24  PerformanceRating         1470 non-null   int64
#  25  RelationshipSatisfaction  1470 non-null   int64
#  26  StandardHours             1470 non-null   int64
#  27  StockOptionLevel          1470 non-null   int64
#  28  TotalWorkingYears         1470 non-null   int64
#  29  TrainingTimesLastYear     1470 non-null   int64
#  30  WorkLifeBalance           1470 non-null   int64
#  31  YearsAtCompany            1470 non-null   int64
#  32  YearsInCurrentRole        1470 non-null   int64
#  33  YearsSinceLastPromotion   1470 non-null   int64
#  34  YearsWithCurrManager      1470 non-null   int64
# dtypes: int32(9), int64(26)
# memory usage: 350.4 KB

# %%
# Defining the Independent and Dependent Variables 
X = df_hr.drop('Attrition', axis=1)
Y = df_hr['Attrition']

# %%
# Scaling of the data 
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
X_scaled = sc.fit_transform(X)

# %%
arr1 = np.array(Y)
arr2 = arr1.reshape(-1,1)
Y = pd.DataFrame(arr2)

# %%
print(X.shape)
print(Y.shape)
# Out:
# (1470, 34)
# (1470, 1)

# %%
# Checking for imbalancced data 
df_hr['Attrition'].value_counts() # We can see the data is imbalanced
# Out:
# 0    1233
# 1     237
# Name: Attrition, dtype: int64

# %%
# Splitting the Data into train and test 
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X_scaled, Y, test_size=0.2, random_state=42)

# %%
model_comparison = {}

# %% [markdown]
# ### Balancing the data using SMOTE Method

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=42)
X_train_resampled, Y_train_resampled = smote.fit_resample(X_train, Y_train)

# %%
import lazypredict
from lazypredict.Supervised import LazyClassifier

# %%
clf = LazyClassifier(verbose=0,ignore_warnings=True)
models, predictions = clf.fit(X_train_resampled, X_test, Y_train_resampled, Y_test)
models
# Out:
# 100%|██████████| 29/29 [00:05<00:00,  5.06it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# NearestCentroid                    0.70               0.70     0.70      0.74
# CalibratedClassifierCV             0.75               0.69     0.69      0.78
# LinearSVC                          0.75               0.69     0.69      0.78
# LinearDiscriminantAnalysis         0.75               0.69     0.69      0.78
# RidgeClassifierCV                  0.75               0.69     0.69      0.78
# RidgeClassifier                    0.75               0.69     0.69      0.78
# LogisticRegression                 0.75               0.69     0.69      0.78
# AdaBoostClassifier                 0.83               0.68     0.68      0.84
# SVC                                0.86               0.68     0.68      0.86
# NuSVC                              0.84               0.68     0.68      0.84
# PassiveAggressiveClassifier        0.69               0.67     0.67      0.74
# SGDClassifier                      0.71               0.67     0.67      0.75
# BernoulliNB                        0.74               0.66     0.66      0.77
# GaussianNB                         0.63               0.64     0.64      0.69
# XGBClassifier                      0.87               0.63     0.63      0.86
# KNeighborsClassifier               0.66               0.63     0.63      0.71
# Perceptron                         0.66               0.63     0.63      0.71
# LGBMClassifier                     0.88               0.62     0.62      0.86
# LabelSpreading                     0.73               0.61     0.61      0.77
# LabelPropagation                   0.73               0.61     0.61      0.77
# BaggingClassifier                  0.85               0.60     0.60      0.84
# ExtraTreesClassifier               0.87               0.57     0.57      0.84
# RandomForestClassifier             0.86               0.56     0.56      0.83
# DecisionTreeClassifier             0.78               0.56     0.56      0.79
# ExtraTreeClassifier                0.74               0.56     0.56      0.76
# QuadraticDiscriminantAnalysis      0.86               0.52     0.52      0.81
# DummyClassifier                    0.87               0.50     0.50      0.81
#
#                                Time Taken
# Model
# NearestCentroid                      0.02
# CalibratedClassifierCV               0.87
# LinearSVC                            0.20
# LinearDiscriminantAnalysis           0.05
# RidgeClassifierCV                    0.04
# RidgeClassifier                      0.04
# LogisticRegression                   0.07
# AdaBoostClassifier                   0.36
# SVC                                  0.20
# NuSVC                                0.24
# PassiveAggressiveClassifier          0.02
# SGDClassifier                        0.05
# BernoulliNB                          0.01
# GaussianNB                           0.02
# XGBClassifier                        0.55
# KNeighborsClassifier                 0.07
# Perceptron                           0.02
# LGBMClassifier                       0.56
# LabelSpreading                       0.48
# LabelPropagation                     0.41
# BaggingClassifier                    0.31
# ExtraTreesClassifier                 0.41
# RandomForestClassifier               0.57
# DecisionTreeClassifier               0.06
# ExtraTreeClassifier                  0.02
# QuadraticDiscriminantAnalysis        0.05
# DummyClassifier                      0.01
